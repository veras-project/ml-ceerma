# %%
import pandas as pd

# %%
excel_file = pd.ExcelFile('../datasetventoinha/falha total_features_ventilador.xlsx')
print("Abas encontradas:", excel_file.sheet_names)

df_window_falhatotal = pd.read_excel('../datasetventoinha/falha total_features_ventilador.xlsx', sheet_name='Features_por_Janela')
df_window_falhatotal.info()

df_window_falhatotal.head()

# %%
excel_file = pd.ExcelFile('../datasetventoinha/falha total_features_ventilador.xlsx')
print("Abas encontradas:", excel_file.sheet_names)

df_window_falhaparcial = pd.read_excel('../datasetventoinha/umquarto_parcialfeatures_ventilador.xlsx', sheet_name='Features_por_Janela')
df_window_falhaparcial.info()

df_window_falhaparcial.head()
# Out:
# Abas encontradas: ['Features_por_Janela', 'Features_Globais']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       1 excel_file = pd.ExcelFile('../datasetventoinha/falha total_features_ventilador.xlsx')
#       2 print("Abas encontradas:", excel_file.sheet_names)
#       3
# ----> 4 df_window_falhaparcial = pd.read_excel('../datasetventoinha/Ventoinha de corrente contínua_Falha na pa parcial_umquarto_Arduino.xlsx', sheet_name='Features_por_Janela')
#       5 df_window_falhaparcial.info()
#       6
#       7 df_window_falhaparcial.head()
#
# File ~/Downloads/ml-ceerma/env/lib/python3.12/site-packages/pandas/io/excel/_base.py:494, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     488     raise ValueError(
#     489         "Engine should not be specified when passing "
#     490         "an ExcelFile - ExcelFile already has the engine set"
#     491     )
#     493 try:
# --> 494     data = io.parse(
#     495         sheet_name=sheet_name,
#     496         header=header,
#     497         names=names,
#     498         index_col=index_col,
#     499         usecols=usecols,
#     500         dtype=dtype,
#     501         converters=converters,
#     502         true_values=true_values,
#     503         false_values=false_values,
#     504         skiprows=skiprows,
#     505         nrows=nrows,
#     506         na_values=na_values,
#     507         keep_default_na=keep_default_na,
#     508         na_filter=na_filter,
#     509         verbose=verbose,
#     510         parse_dates=parse_dates,
#     511         date_format=date_format,
#     512         thousands=thousands,
#     513         decimal=decimal,
#     514         comment=comment,
#     515         skipfooter=skipfooter,
#     516         dtype_backend=dtype_backend,
#     517     )
#     518 finally:
#     519     # make sure to close opened file handles
#     520     if should_close:
#
# File ~/Downloads/ml-ceerma/env/lib/python3.12/site-packages/pandas/io/excel/_base.py:1780, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_format, thousands, comment, skipfooter, dtype_backend, **kwds)
#    1630 def parse(
#    1631     self,
#    1632     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)   1649     **kwds,
#    1650 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1651     """
#    1652     Parse specified sheet(s) into a DataFrame.
#    1653
#    (...)   1778     >>> file.parse()  # doctest: +SKIP
#    1779     """
# -> 1780     return self._reader.parse(
#    1781         sheet_name=sheet_name,
#    1782         header=header,
#    1783         names=names,
#    1784         index_col=index_col,
#    1785         usecols=usecols,
#    1786         converters=converters,
#    1787         true_values=true_values,
#    1788         false_values=false_values,
#    1789         skiprows=skiprows,
#    1790         nrows=nrows,
#    1791         na_values=na_values,
#    1792         parse_dates=parse_dates,
#    1793         date_format=date_format,
#    1794         thousands=thousands,
#    1795         comment=comment,
#    1796         skipfooter=skipfooter,
#    1797         dtype_backend=dtype_backend,
#    1798         **kwds,
#    1799     )
#
# File ~/Downloads/ml-ceerma/env/lib/python3.12/site-packages/pandas/io/excel/_base.py:753, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, dtype_backend, **kwds)
#     750     print(f"Reading sheet {asheetname}")
#     752 if isinstance(asheetname, str):
# --> 753     sheet = self.get_sheet_by_name(asheetname)
#     754 else:  # assume an integer if not a string
#     755     sheet = self.get_sheet_by_index(asheetname)
#
# File ~/Downloads/ml-ceerma/env/lib/python3.12/site-packages/pandas/io/excel/_openpyxl.py:589, in OpenpyxlReader.get_sheet_by_name(self, name)
#     588 def get_sheet_by_name(self, name: str):
# --> 589     self.raise_if_bad_sheet_by_name(name)
#     590     return self.book[name]
#
# File ~/Downloads/ml-ceerma/env/lib/python3.12/site-packages/pandas/io/excel/_base.py:605, in BaseExcelReader.raise_if_bad_sheet_by_name(self, name)
#     603 def raise_if_bad_sheet_by_name(self, name: str) -> None:
#     604     if name not in self.sheet_names:
# --> 605         raise ValueError(f"Worksheet named '{name}' not found")
#
# ValueError: Worksheet named 'Features_por_Janela' not found

# %%
excel_file = pd.ExcelFile('../datasetventoinha/falha total_features_ventilador.xlsx')
print("Abas encontradas:", excel_file.sheet_names)

df_window_semfalha = pd.read_excel('../datasetventoinha/falha total_features_ventilador.xlsx', sheet_name='Features_por_Janela')
df_window_semfalha.info()

df_window_semfalha.head()
